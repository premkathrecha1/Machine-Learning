# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('/content/sample_data/lena.png', 0)

kernel = np.ones((5,5), np.float32)/25
filtered = cv2.filter2D(img, -1, kernel)

plt.imshow(filtered, cmap='gray')
plt.show()
